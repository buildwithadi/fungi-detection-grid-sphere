# %%
import pandas as pd

# %%
dataset = '../data/data_v1.csv'

# %%
df = pd.read_csv(dataset)

# %%
df.head()
# Out:
#     id         paper_id                  primers  longitude  latitude  \
# 0  884  Rincon_2021_1GU  AML1/AML2 then NS31/AM1   -5.86022   6.13511
# 1  887  Rincon_2021_1GU  AML1/AML2 then NS31/AM1   -6.71673   4.76278
# 2  888   Vasar_2021_1HW               WANDA/AML2  -48.85250 -15.81000
# 3  889  Rincon_2021_1GU  AML1/AML2 then NS31/AM1   -5.85256   6.13115
# 4  890  Rincon_2021_1GU  AML1/AML2 then NS31/AM1   -6.65290   5.59485
#
#        continent sample_type  marker_size      Biome   MAT   MAP    pH  \
# 0         Africa        soil       616023   cropland  25.2  1309  7.30
# 1         Africa        soil       495310   cropland  26.0  1459  5.60
# 2  South America        soil       146654  grassland  21.0  1926  3.36
# 3         Africa        soil       644559   cropland  25.2  1336  7.60
# 4         Africa        soil       502723   cropland  25.3  1337  7.60
#
#   year_of_sampling  plants_dominant target_gene sequencing_platform  \
# ...

# %%
df.fungus_species.value_counts()
# Out:
# fungus_species
# Claroideoglomus sp.         4295
# Entrophospora lamellosa     2969
# Diversispora sp.            2851
# Acaulospora sp.             2325
# Paraglomus sp.              1590
# Archaeospora sp.            1540
# Rhizophagus intraradices    1232
# Diversispora epigaea         657
# Archaeospora trappei         589
# Paraglomus laccatum          567
# Paraglomus brasilianum       493
# Scutellospora sp.            367
# Paraglomus occultum          234
# Diversispora trimurales      217
# Name: count, dtype: int64
